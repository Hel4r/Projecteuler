# %%
import numpy as np

# %% [markdown]
# Problem 33
#
# The fraction $49/98$ is a curious fraction, as an inexperienced mathematician in attempting to simplify it may incorrectly believe that $49/98 = 4/8$, which is correct, is obtained by cancelling the $9$s.
# We shall consider fractions like, $30/50 = 3/5$, to be trivial examples.
# There are exactly four non-trivial examples of this type of fraction, less than one in value, and containing two digits in the numerator and denominator.
# If the product of these four fractions is given in its lowest common terms, find the value of the denominator.

# %% [markdown]
# Więc tak: sprawdzam liczby od 10 do 99, jeżeli ich iloraz jest taki jak iloraz ze skreślonymi powtarzającymi się cyframi, to dodaję do list licznik i mianownik.
# Najpierw biorę na tape sytuację, gdzie cyfra jedności licznika skraca cyfrę dziesiątek mianownika.

# %%
nums = []
dens = []
for n in range(10, 99):
    for d in range(n+1, 100):
        n1 = str(n)[0]
        n2 = str(n)[1]
        d1 = str(d)[0]
        d2 = str(d)[1]
        if n2 == d1 and d2 != '0' and n/d == int(n1)/int(d2):
            print(f'{n}/{d}')
            nums.append(n1)
            dens.append(d2)
print([int(n) for n in nums])
print([int(d) for d in dens])
# Out:
# 16/64
# 19/95
# 26/65
# 49/98
# [1, 1, 2, 4]
# [4, 5, 5, 8]

# %% [markdown]
# odp: 100

# %% [markdown]
# Problem 37
#
# The number $3797$ has an interesting property. Being prime itself, it is possible to continuously remove digits from left to right, and remain prime at each stage: $3797$, $797$, $97$, and $7$. Similarly we can work from right to left: $3797$, $379$, $37$, and $3$.
# Find the sum of the only eleven primes that are both truncatable from left to right and right to left.
#
# NOTE: $2$, $3$, $5$, and $7$ are not considered to be truncatable primes.

# %%
# def prime(n):
#     if n < 2: return False
#     for k in range(2, int(n**(0.5))+1):
#         if n % k == 0:
#             return False
#     return True

# liczby = []
# k = 10
# while(len(liczby) < 1):
#     bool = True
#     if prime(n) == False:
#         bool = False
#     else:
#         for i in range(1, len(str(k))):
#             if prime(int(str(k)[i:])) == False or prime(int(str(k)[:-i])) == False:
#                 bool = False
#                 break

#     if bool == True:
#         liczby.append(k)
#     k+=1

# print(liczby)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 12
#      10 while(len(liczby) < 1):
#      11     bool = True
# ---> 12     if prime(n) == False:
#      13         bool = False
#      14     else:
#
# Cell In[40], line 3, in prime(n)
#       1 def prime(n):
#       2     if n < 2: return False
# ----> 3     for k in range(2, int(n**(0.5))+1):
#       4         if n % k == 0:
#       5             return False
#
# KeyboardInterrupt:

# %% [markdown]
# Dochodzę do wniosku, że trzeba to zrobić algorytmicznie; zamiast sprawdzać coraz większe liczby poprzez obcinanie ich, musimy brać liczby pierwsze i 'dokładać' im liczby na brzegach w taki sposób, żeby pozostały pierwsze. Problem może być taki, że czasem to, że mamy liczbę abcde spełniającą nasze warunki, nie możemy dostać kolejnej tylko poprzez dołożenie jednej cyfry z tej lub drugiej strony, może trzeba dołożyć na obu brzegach i to nie po jednej?
